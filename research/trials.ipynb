# %%
d = {"key": "value"}

# %%
print(d.keys())
# Out:
# dict_keys(['key'])

# %%
print("Hello")
# Out:
# Hello

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"name": "Bhavin", "age": 24})

# %%
name_of_person = d2.name
print(name_of_person)
# Out:
# Bhavin
